# %% [markdown]
# ## Installation
#
#
# ### 1. Clone the repository
# Open a terminal in the directory where you want the project, then run:
#
# ```bash
# git clone https://github.com/seppedijkstra/Quantum_Game.git
# cd Quantum_Game
# ````
#
# ### 2. Install dependencies
#
# Install all required packages by using requirements.txt:
#
# ```bash
# pip install -r requirements.txt
# ```
#
# ### 3. Build the notebooks
#
# To build the Jupyter Book from the notebooks, run:
#
# ```bash
# python -c "from jupyter_book.cli.main import main; import sys; sys.argv = ['jupyter-book', 'build', '.']; main()"
# ```
#
# The built book will be available inside the **`_build/`** folder.

# %%
import ipywidgets as widgets
from IPython.display import display

# Define options
options = ["Huey", "Dewey", "Louie"]
correct_answer = "Dewey"

# Create radio buttons
radio = widgets.RadioButtons(
    options=options,
    description='Drone:',
    disabled=False
)

# Output widget for feedback
output = widgets.Output()

def check_answer(change):
    output.clear_output()
    with output:
        if change['new'] == correct_answer:
            print("✅ Correct!")
        else:
            print("❌ Try again.")

# Attach event listener
radio.observe(check_answer, names='value')

# Show in notebook
display(radio, output)
# Out:
# RadioButtons(description='Drone:', options=('Huey', 'Dewey', 'Louie'), value='Huey')
# Output()
